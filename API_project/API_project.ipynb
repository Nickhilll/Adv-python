# %% [markdown]
# # Project 2 - Stock market API Project

# %%
# %pip install python-dotenv plotly nbformat
# Out:
# Requirement already satisfied: python-dotenv in c:\users\nikhil\desktop\advpython\repository\venv\lib\site-packages (1.0.1)
# Requirement already satisfied: plotly in c:\users\nikhil\desktop\advpython\repository\venv\lib\site-packages (5.24.1)
# Requirement already satisfied: nbformat in c:\users\nikhil\desktop\advpython\repository\venv\lib\site-packages (5.10.4)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\nikhil\desktop\advpython\repository\venv\lib\site-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in c:\users\nikhil\desktop\advpython\repository\venv\lib\site-packages (from plotly) (24.2)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\nikhil\desktop\advpython\repository\venv\lib\site-packages (from nbformat) (2.21.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\nikhil\desktop\advpython\repository\venv\lib\site-packages (from nbformat) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\nikhil\desktop\advpython\repository\venv\lib\site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in c:\users\nikhil\desktop\advpython\repository\venv\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\nikhil\desktop\advpython\repository\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\nikhil\desktop\advpython\repository\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\nikhil\desktop\advpython\repository\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\nikhil\desktop\advpython\repository\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.21.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\nikhil\desktop\advpython\repository\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\nikhil\desktop\advpython\repository\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (308)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load the API key from .env file

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
api_key = os.getenv('API_KEY')

# %% [markdown]
# ## 1. Get the company stock symbol

# %%
import requests

url = "https://alpha-vantage.p.rapidapi.com/query"

querystring = {"datatype":"json","keywords":"State Bank of India","function":"SYMBOL_SEARCH"}

headers = {
	"x-rapidapi-key": api_key,
	"x-rapidapi-host": "alpha-vantage.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
response.json()
# Out:
# {'bestMatches': [{'1. symbol': 'SBIN.BSE',
#    '2. name': 'State Bank of India',
#    '3. type': 'Equity',
#    '4. region': 'India/Bombay',
#    '5. marketOpen': '09:15',
#    '6. marketClose': '15:30',
#    '7. timezone': 'UTC+5.5',
#    '8. currency': 'INR',
#    '9. matchScore': '1.0000'},
#   {'1. symbol': 'SBKFF',
#    '2. name': 'State Bank of India',
#    '3. type': 'Equity',
#    '4. region': 'United States',
#    '5. marketOpen': '09:30',
#    '6. marketClose': '16:00',
#    '7. timezone': 'UTC-04',
#    '8. currency': 'USD',
#    '9. matchScore': '1.0000'},
#   {'1. symbol': 'SID.FRK',
#    '2. name': 'State Bank of India',
#    '3. type': 'Equity',
#    '4. region': 'Frankfurt',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '20:00',
#    '7. timezone': 'UTC+02',
#    '8. currency': 'EUR',
#    '9. matchScore': '1.0000'},
#   {'1. symbol': 'SBID.LON',
#    '2. name': 'State Bank of India GDR',
#    '3. type': 'Equity',
#    '4. region': 'United Kingdom',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '16:30',
#    '7. timezone': 'UTC+01',
#    '8. currency': 'USD',
#    '9. matchScore': '0.9048'}]}

# %% [markdown]
# ## Get daily stock details for SBIN.BSE

# %%
import requests

url = "https://alpha-vantage.p.rapidapi.com/query"

querystring = {"function":"TIME_SERIES_DAILY","symbol":"SBIN.BSE","outputsize":"compact","datatype":"json"}

headers = {
	"x-rapidapi-key": api_key,
	"x-rapidapi-host": "alpha-vantage.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

data = response.json()
data
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'SBIN.BSE',
#   '3. Last Refreshed': '2025-01-03',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2025-01-03': {'1. open': '801.9000',
#    '2. high': '809.7000',
#    '3. low': '792.2500',
#    '4. close': '793.5000',
#    '5. volume': '387698'},
#   '2025-01-02': {'1. open': '795.0000',
#    '2. high': '802.4000',
#    '3. low': '786.3000',
#    '4. close': '801.0500',
#    '5. volume': '711599'},
#   '2025-01-01': {'1. open': '796.8500',
#    '2. high': '798.5000',
#    '3. low': '789.6000',
#    '4. close': '793.3500',
#    '5. volume': '356031'},
#   '2024-12-31': {'1. open': '788.7500',
#    '2. high': '798.9500',
#    '3. low': '787.0000',
#    '4. close': '795.0500',
#    '5. volume': '283620'},
#   '2024-12-30': {'1. open': '802.7000',
#    '2. high': '808.0000',
#    '3. low': '785.2000',
#    '4. close': '788.3000',
#    '5. volume': '686161'},
#   '2024-12-27': {'1. open': '817.2500',
#    '2. high': '818.7500',
#    '3. low': '797.2500',
#    '4. close': '799.5500',
#    '5. volume': '1061163'},
#   '2024-12-26': {'1. open': '813.0000',
#    '2. high': '822.9500',
#    '3. low': '808.0000',
#    '4. close': '811.6500',
#    '5. volume': '194920'},
#   '2024-12-24': {'1. open': '825.0000',
#    '2. high': '825.5500',
#    '3. low': '809.2000',
#    '4. close': '811.8500',
#    '5. volume': '431577'},
#   '2024-12-23': {'1. open': '818.3500',
#    '2. high': '823.9000',
#    '3. low': '812.4000',
#    '4. close': '820.9500',
#    '5. volume': '281649'},
#   '2024-12-20': {'1. open': '833.8000',
#    '2. high': '836.4000',
#    '3. low': '810.0000',
#    '4. close': '812.5000',
#    '5. volume': '467910'},
#   '2024-12-19': {'1. open': '822.0500',
#    '2. high': '837.9000',
#    '3. low': '820.1000',
#    '4. close': '832.8000',
#    '5. volume': '309033'},
#   '2024-12-18': {'1. open': '850.2000',
#    '2. high': '850.8000',
#    '3. low': '836.7000',
#    '4. close': '839.0500',
#    '5. volume': '172425'},
#   '2024-12-17': {'1. open': '859.7500',
#    '2. high': '862.9500',
#    '3. low': '847.1500',
#    '4. close': '850.2000',
#    '5. volume': '143409'},
#   '2024-12-16': {'1. open': '859.0000',
#    '2. high': '866.2000',
#    '3. low': '857.8000',
#    '4. close': '860.7000',
#    '5. volume': '252691'},
#   '2024-12-13': {'1. open': '853.7000',
#    '2. high': '863.0000',
#    '3. low': '835.0000',
#    '4. close': '861.7000',
#    '5. volume': '455324'},
#   '2024-12-12': {'1. open': '862.5000',
#    '2. high': '864.2000',
#    '3. low': '851.2500',
#    '4. close': '853.7500',
#    '5. volume': '179011'},
#   '2024-12-11': {'1. open': '865.7500',
#    '2. high': '869.7500',
#    '3. low': '860.8000',
#    '4. close': '861.5500',
#    '5. volume': '342069'},
#   '2024-12-10': {'1. open': '862.0000',
#    '2. high': '868.8500',
#    '3. low': '858.5000',
#    '4. close': '867.6000',
#    '5. volume': '197287'},
#   '2024-12-09': {'1. open': '862.9500',
#    '2. high': '866.8000',
#    '3. low': '856.7500',
#    '4. close': '857.8500',
#    '5. volume': '646144'},
#   '2024-12-06': {'1. open': '866.9500',
#    '2. high': '875.5000',
#    '3. low': '856.8500',
#    '4. close': '864.0000',
#    '5. volume': '431320'},
#   '2024-12-05': {'1. open': '861.6500',
#    '2. high': '871.0000',
#    '3. low': '855.6500',
#    '4. close': '864.8500',
#    '5. volume': '379508'},
#   '2024-12-04': {'1. open': '854.4000',
#    '2. high': '863.8000',
#    '3. low': '850.2500',
#    '4. close': '859.4500',
#    '5. volume': '679548'},
#   '2024-12-03': {'1. open': '836.4500',
#    '2. high': '856.6000',
#    '3. low': '836.4500',
#    '4. close': '853.9500',
#    '5. volume': '370485'},
#   '2024-12-02': {'1. open': '836.2000',
#    '2. high': '842.0000',
#    '3. low': '832.8000',
#    '4. close': '836.2000',
#    '5. volume': '526054'},
#   '2024-11-29': {'1. open': '842.0000',
#    '2. high': '843.8500',
#    '3. low': '831.5000',
#    '4. close': '839.0000',
#    '5. volume': '757635'},
#   '2024-11-28': {'1. open': '834.9500',
#    '2. high': '845.7000',
#    '3. low': '830.3500',
#    '4. close': '838.7500',
#    '5. volume': '811586'},
#   '2024-11-27': {'1. open': '839.3000',
#    '2. high': '842.1500',
#    '3. low': '832.0000',
#    '4. close': '834.2000',
#    '5. volume': '502957'},
#   '2024-11-26': {'1. open': '844.7500',
#    '2. high': '846.7000',
#    '3. low': '835.2000',
#    '4. close': '839.3500',
#    '5. volume': '448647'},
#   '2024-11-25': {'1. open': '826.2500',
#    '2. high': '849.3000',
#    '3. low': '825.9500',
#    '4. close': '844.7500',
#    '5. volume': '1612713'},
#   '2024-11-22': {'1. open': '785.6500',
#    '2. high': '819.7500',
#    '3. low': '784.3000',
#    '4. close': '816.0500',
#    '5. volume': '1534393'},
#   '2024-11-21': {'1. open': '800.0000',
#    '2. high': '800.0000',
#    '3. low': '761.6500',
#    '4. close': '780.8500',
#    '5. volume': '804079'},
#   '2024-11-19': {'1. open': '817.5500',
#    '2. high': '820.1000',
#    '3. low': '800.1000',
#    '4. close': '802.0000',
#    '5. volume': '467072'},
#   '2024-11-18': {'1. open': '810.0500',
#    '2. high': '816.6500',
#    '3. low': '799.2000',
#    '4. close': '813.7000',
#    '5. volume': '378989'},
#   '2024-11-14': {'1. open': '809.9500',
#    '2. high': '817.8500',
#    '3. low': '801.1000',
#    '4. close': '804.0500',
#    '5. volume': '720597'},
#   '2024-11-13': {'1. open': '822.5000',
#    '2. high': '831.6500',
#    '3. low': '804.4500',
#    '4. close': '808.3500',
#    '5. volume': '454522'},
#   '2024-11-12': {'1. open': '851.0000',
#    '2. high': '853.0000',
#    '3. low': '824.1000',
#    '4. close': '826.4000',
#    '5. volume': '467134'},
#   '2024-11-11': {'1. open': '847.0000',
#    '2. high': '853.6500',
#    '3. low': '841.4500',
#    '4. close': '847.8000',
#    '5. volume': '1417460'},
#   '2024-11-08': {'1. open': '860.0000',
#    '2. high': '863.6500',
#    '3. low': '834.3000',
#    '4. close': '843.2500',
#    '5. volume': '1106664'},
#   '2024-11-07': {'1. open': '860.0500',
#    '2. high': '862.4500',
#    '3. low': '846.7000',
#    '4. close': '859.2500',
#    '5. volume': '494821'},
#   '2024-11-06': {'1. open': '850.0000',
#    '2. high': '861.0000',
#    '3. low': '846.2000',
#    '4. close': '854.7500',
#    '5. volume': '896339'},
#   '2024-11-05': {'1. open': '829.0000',
#    '2. high': '851.2000',
#    '3. low': '826.1000',
#    '4. close': '849.2000',
#    '5. volume': '1335383'},
#   '2024-11-04': {'1. open': '822.6500',
#    '2. high': '837.5000',
#    '3. low': '807.0500',
#    '4. close': '829.8500',
#    '5. volume': '458939'},
#   '2024-10-31': {'1. open': '821.9500',
#    '2. high': '828.0000',
#    '3. low': '813.4500',
#    '4. close': '820.5000',
#    '5. volume': '497763'},
#   '2024-10-30': {'1. open': '830.0000',
#    '2. high': '832.9000',
#    '3. low': '821.0500',
#    '4. close': '822.4000',
#    '5. volume': '322347'},
#   '2024-10-29': {'1. open': '796.5000',
#    '2. high': '834.5000',
#    '3. low': '790.5000',
#    '4. close': '832.6500',
#    '5. volume': '1593501'},
#   '2024-10-28': {'1. open': '783.2000',
#    '2. high': '803.9500',
#    '3. low': '783.2000',
#    '4. close': '792.0500',
#    '5. volume': '675658'},
#   '2024-10-25': {'1. open': '798.4500',
#    '2. high': '800.0000',
#    '3. low': '772.0500',
#    '4. close': '780.6000',
#    '5. volume': '650630'},
#   '2024-10-24': {'1. open': '786.0500',
#    '2. high': '796.8000',
#    '3. low': '784.5000',
#    '4. close': '794.7000',
#    '5. volume': '183971'},
#   '2024-10-23': {'1. open': '790.0000',
#    '2. high': '792.5000',
#    '3. low': '779.6000',
#    '4. close': '785.9500',
#    '5. volume': '467975'},
#   '2024-10-22': {'1. open': '814.1500',
#    '2. high': '816.3500',
#    '3. low': '787.6000',
#    '4. close': '790.4500',
#    '5. volume': '604778'},
#   '2024-10-21': {'1. open': '822.0500',
#    '2. high': '826.3500',
#    '3. low': '809.1000',
#    '4. close': '814.1500',
#    '5. volume': '584223'},
#   '2024-10-18': {'1. open': '811.0000',
#    '2. high': '822.4000',
#    '3. low': '803.1000',
#    '4. close': '819.9500',
#    '5. volume': '429099'},
#   '2024-10-17': {'1. open': '806.0500',
#    '2. high': '819.2500',
#    '3. low': '806.0500',
#    '4. close': '810.9000',
#    '5. volume': '948591'},
#   '2024-10-16': {'1. open': '801.0500',
#    '2. high': '808.9000',
#    '3. low': '801.0500',
#    '4. close': '805.8500',
#    '5. volume': '142406'},
#   '2024-10-15': {'1. open': '805.0000',
#    '2. high': '807.6000',
#    '3. low': '801.5000',
#    '4. close': '804.6000',
#    '5. volume': '314354'},
#   '2024-10-14': {'1. open': '800.1500',
#    '2. high': '809.0000',
#    '3. low': '800.1500',
#    '4. close': '805.2500',
#    '5. volume': '755286'},
#   '2024-10-11': {'1. open': '797.0000',
#    '2. high': '802.5000',
#    '3. low': '793.0000',
#    '4. close': '800.0000',
#    '5. volume': '381115'},
#   '2024-10-10': {'1. open': '799.9000',
#    '2. high': '804.3500',
#    '3. low': '795.0500',
#    '4. close': '796.9500',
#    '5. volume': '163966'},
#   '2024-10-09': {'1. open': '787.9500',
#    '2. high': '805.0000',
#    '3. low': '782.5500',
#    '4. close': '797.0000',
#    '5. volume': '807499'},
#   '2024-10-08': {'1. open': '771.1000',
#    '2. high': '784.5000',
#    '3. low': '771.1000',
#    '4. close': '782.0500',
#    '5. volume': '295906'},
#   '2024-10-07': {'1. open': '797.0500',
#    '2. high': '803.9000',
#    '3. low': '765.5500',
#    '4. close': '769.8000',
#    '5. volume': '1587972'},
#   '2024-10-04': {'1. open': '790.3000',
#    '2. high': '809.6500',
#    '3. low': '785.2000',
#    '4. close': '796.6000',
#    '5. volume': '1154183'},
#   '2024-10-03': {'1. open': '787.4000',
#    '2. high': '803.9500',
#    '3. low': '784.3500',
#    '4. close': '794.3500',
#    '5. volume': '768391'},
#   '2024-10-01': {'1. open': '788.9500',
#    '2. high': '799.7500',
#    '3. low': '788.2500',
#    '4. close': '797.0000',
#    '5. volume': '227883'},
#   '2024-09-30': {'1. open': '801.1500',
#    '2. high': '802.5000',
#    '3. low': '786.1500',
#    '4. close': '787.6000',
#    '5. volume': '1054719'},
#   '2024-09-27': {'1. open': '802.0000',
#    '2. high': '807.8500',
#    '3. low': '798.4000',
#    '4. close': '802.6500',
#    '5. volume': '669965'},
#   '2024-09-26': {'1. open': '795.1500',
#    '2. high': '803.0000',
#    '3. low': '791.5500',
#    '4. close': '801.9000',
#    '5. volume': '432917'},
#   '2024-09-25': {'1. open': '798.2500',
#    '2. high': '798.2500',
#    '3. low': '788.6500',
#    '4. close': '792.9500',
#    '5. volume': '524539'},
#   '2024-09-24': {'1. open': '800.0000',
#    '2. high': '804.1000',
#    '3. low': '796.6500',
#    '4. close': '798.3500',
#    '5. volume': '427650'},
#   '2024-09-23': {'1. open': '785.0500',
#    '2. high': '804.9000',
#    '3. low': '785.0000',
#    '4. close': '801.8000',
#    '5. volume': '1415077'},
#   '2024-09-20': {'1. open': '794.0500',
#    '2. high': '794.4000',
#    '3. low': '779.5000',
#    '4. close': '781.9000',
#    '5. volume': '1481791'},
#   '2024-09-19': {'1. open': '794.1500',
#    '2. high': '801.2500',
#    '3. low': '784.1000',
#    '4. close': '790.3500',
#    '5. volume': '402071'},
#   '2024-09-18': {'1. open': '783.5500',
#    '2. high': '794.5000',
#    '3. low': '781.3000',
#    '4. close': '792.3500',
#    '5. volume': '681430'},
#   '2024-09-17': {'1. open': '786.0000',
#    '2. high': '787.5000',
#    '3. low': '780.6500',
#    '4. close': '783.0500',
#    '5. volume': '240500'},
#   '2024-09-16': {'1. open': '793.4500',
#    '2. high': '795.3000',
#    '3. low': '784.1000',
#    '4. close': '785.4500',
#    '5. volume': '624666'},
#   '2024-09-13': {'1. open': '790.8500',
#    '2. high': '795.0000',
#    '3. low': '784.8500',
#    '4. close': '790.5500',
#    '5. volume': '1064575'},
#   '2024-09-12': {'1. open': '775.0000',
#    '2. high': '789.7000',
#    '3. low': '772.9000',
#    '4. close': '788.0500',
#    '5. volume': '312891'},
#   '2024-09-11': {'1. open': '781.6500',
#    '2. high': '788.0000',
#    '3. low': '765.6500',
#    '4. close': '768.3000',
#    '5. volume': '521913'},
#   '2024-09-10': {'1. open': '788.6500',
#    '2. high': '788.9500',
#    '3. low': '777.6500',
#    '4. close': '782.6000',
#    '5. volume': '582017'},
#   '2024-09-09': {'1. open': '785.0000',
#    '2. high': '788.0500',
#    '3. low': '771.3000',
#    '4. close': '784.3000',
#    '5. volume': '1433332'},
#   '2024-09-06': {'1. open': '813.9000',
#    '2. high': '813.9000',
#    '3. low': '777.0500',
#    '4. close': '782.6000',
#    '5. volume': '2498701'},
#   '2024-09-05': {'1. open': '818.0000',
#    '2. high': '821.9000',
#    '3. low': '814.3000',
#    '4. close': '818.6000',
#    '5. volume': '318031'},
#   '2024-09-04': {'1. open': '813.0000',
#    '2. high': '818.6500',
#    '3. low': '813.0000',
#    '4. close': '816.5000',
#    '5. volume': '278846'},
#   '2024-09-03': {'1. open': '821.2000',
#    '2. high': '825.9000',
#    '3. low': '816.7500',
#    '4. close': '824.7500',
#    '5. volume': '293326'},
#   '2024-09-02': {'1. open': '816.4500',
#    '2. high': '825.3000',
#    '3. low': '813.0000',
#    '4. close': '822.1000',
#    '5. volume': '1129356'},
#   '2024-08-30': {'1. open': '818.4500',
#    '2. high': '820.3500',
#    '3. low': '814.3000',
#    '4. close': '815.6500',
#    '5. volume': '598533'},
#   '2024-08-29': {'1. open': '809.3500',
#    '2. high': '815.9500',
#    '3. low': '807.3000',
#    '4. close': '814.5000',
#    '5. volume': '271349'},
#   '2024-08-28': {'1. open': '813.8000',
#    '2. high': '817.1000',
#    '3. low': '806.9000',
#    '4. close': '809.3000',
#    '5. volume': '196716'},
#   '2024-08-27': {'1. open': '816.8500',
#    '2. high': '819.3000',
#    '3. low': '811.0500',
#    '4. close': '815.1500',
#    '5. volume': '464853'},
#   '2024-08-26': {'1. open': '819.3500',
#    '2. high': '823.3500',
#    '3. low': '814.2000',
#    '4. close': '815.3500',
#    '5. volume': '1278721'},
#   '2024-08-23': {'1. open': '821.0500',
#    '2. high': '821.7000',
#    '3. low': '814.2000',
#    '4. close': '815.2500',
#    '5. volume': '560060'},
#   '2024-08-22': {'1. open': '819.8500',
#    '2. high': '823.7000',
#    '3. low': '817.4000',
#    '4. close': '820.1500',
#    '5. volume': '494896'},
#   '2024-08-21': {'1. open': '820.0000',
#    '2. high': '821.0000',
#    '3. low': '811.4000',
#    '4. close': '815.8000',
#    '5. volume': '248423'},
#   '2024-08-20': {'1. open': '818.7500',
#    '2. high': '822.9000',
#    '3. low': '813.2000',
#    '4. close': '820.0000',
#    '5. volume': '308095'},
#   '2024-08-19': {'1. open': '814.0500',
#    '2. high': '825.0000',
#    '3. low': '812.3500',
#    '4. close': '813.6500',
#    '5. volume': '743917'},
#   '2024-08-16': {'1. open': '803.5000',
#    '2. high': '815.1000',
#    '3. low': '803.2000',
#    '4. close': '812.4500',
#    '5. volume': '768630'},
#   '2024-08-14': {'1. open': '800.7000',
#    '2. high': '809.0000',
#    '3. low': '800.4000',
#    '4. close': '802.9500',
#    '5. volume': '287718'},
#   '2024-08-13': {'1. open': '813.1000',
#    '2. high': '819.4000',
#    '3. low': '795.1000',
#    '4. close': '797.3000',
#    '5. volume': '641102'},
#   '2024-08-12': {'1. open': '819.2000',
#    '2. high': '822.6000',
#    '3. low': '810.8500',
#    '4. close': '813.0000',
#    '5. volume': '1142861'},
#   '2024-08-09': {'1. open': '816.8000',
#    '2. high': '829.9000',
#    '3. low': '809.8500',
#    '4. close': '824.2000',
#    '5. volume': '822817'}}}

# %%
data.keys()
# Out:
# dict_keys(['Meta Data', 'Time Series (Daily)'])

# %%
daily = data['Time Series (Daily)']
daily
# Out:
# {'2025-01-03': {'1. open': '801.9000',
#   '2. high': '809.7000',
#   '3. low': '792.2500',
#   '4. close': '793.5000',
#   '5. volume': '387698'},
#  '2025-01-02': {'1. open': '795.0000',
#   '2. high': '802.4000',
#   '3. low': '786.3000',
#   '4. close': '801.0500',
#   '5. volume': '711599'},
#  '2025-01-01': {'1. open': '796.8500',
#   '2. high': '798.5000',
#   '3. low': '789.6000',
#   '4. close': '793.3500',
#   '5. volume': '356031'},
#  '2024-12-31': {'1. open': '788.7500',
#   '2. high': '798.9500',
#   '3. low': '787.0000',
#   '4. close': '795.0500',
#   '5. volume': '283620'},
#  '2024-12-30': {'1. open': '802.7000',
#   '2. high': '808.0000',
#   '3. low': '785.2000',
#   '4. close': '788.3000',
#   '5. volume': '686161'},
#  '2024-12-27': {'1. open': '817.2500',
#   '2. high': '818.7500',
#   '3. low': '797.2500',
#   '4. close': '799.5500',
#   '5. volume': '1061163'},
#  '2024-12-26': {'1. open': '813.0000',
#   '2. high': '822.9500',
#   '3. low': '808.0000',
#   '4. close': '811.6500',
#   '5. volume': '194920'},
#  '2024-12-24': {'1. open': '825.0000',
#   '2. high': '825.5500',
#   '3. low': '809.2000',
#   '4. close': '811.8500',
#   '5. volume': '431577'},
#  '2024-12-23': {'1. open': '818.3500',
#   '2. high': '823.9000',
#   '3. low': '812.4000',
#   '4. close': '820.9500',
#   '5. volume': '281649'},
#  '2024-12-20': {'1. open': '833.8000',
#   '2. high': '836.4000',
#   '3. low': '810.0000',
#   '4. close': '812.5000',
#   '5. volume': '467910'},
#  '2024-12-19': {'1. open': '822.0500',
#   '2. high': '837.9000',
#   '3. low': '820.1000',
#   '4. close': '832.8000',
#   '5. volume': '309033'},
#  '2024-12-18': {'1. open': '850.2000',
#   '2. high': '850.8000',
#   '3. low': '836.7000',
#   '4. close': '839.0500',
#   '5. volume': '172425'},
#  '2024-12-17': {'1. open': '859.7500',
#   '2. high': '862.9500',
#   '3. low': '847.1500',
#   '4. close': '850.2000',
#   '5. volume': '143409'},
#  '2024-12-16': {'1. open': '859.0000',
#   '2. high': '866.2000',
#   '3. low': '857.8000',
#   '4. close': '860.7000',
#   '5. volume': '252691'},
#  '2024-12-13': {'1. open': '853.7000',
#   '2. high': '863.0000',
#   '3. low': '835.0000',
#   '4. close': '861.7000',
#   '5. volume': '455324'},
#  '2024-12-12': {'1. open': '862.5000',
#   '2. high': '864.2000',
#   '3. low': '851.2500',
#   '4. close': '853.7500',
#   '5. volume': '179011'},
#  '2024-12-11': {'1. open': '865.7500',
#   '2. high': '869.7500',
#   '3. low': '860.8000',
#   '4. close': '861.5500',
#   '5. volume': '342069'},
#  '2024-12-10': {'1. open': '862.0000',
#   '2. high': '868.8500',
#   '3. low': '858.5000',
#   '4. close': '867.6000',
#   '5. volume': '197287'},
#  '2024-12-09': {'1. open': '862.9500',
#   '2. high': '866.8000',
#   '3. low': '856.7500',
#   '4. close': '857.8500',
#   '5. volume': '646144'},
#  '2024-12-06': {'1. open': '866.9500',
#   '2. high': '875.5000',
#   '3. low': '856.8500',
#   '4. close': '864.0000',
#   '5. volume': '431320'},
#  '2024-12-05': {'1. open': '861.6500',
#   '2. high': '871.0000',
#   '3. low': '855.6500',
#   '4. close': '864.8500',
#   '5. volume': '379508'},
#  '2024-12-04': {'1. open': '854.4000',
#   '2. high': '863.8000',
#   '3. low': '850.2500',
#   '4. close': '859.4500',
#   '5. volume': '679548'},
#  '2024-12-03': {'1. open': '836.4500',
#   '2. high': '856.6000',
#   '3. low': '836.4500',
#   '4. close': '853.9500',
#   '5. volume': '370485'},
#  '2024-12-02': {'1. open': '836.2000',
#   '2. high': '842.0000',
#   '3. low': '832.8000',
#   '4. close': '836.2000',
#   '5. volume': '526054'},
#  '2024-11-29': {'1. open': '842.0000',
#   '2. high': '843.8500',
#   '3. low': '831.5000',
#   '4. close': '839.0000',
#   '5. volume': '757635'},
#  '2024-11-28': {'1. open': '834.9500',
#   '2. high': '845.7000',
#   '3. low': '830.3500',
#   '4. close': '838.7500',
#   '5. volume': '811586'},
#  '2024-11-27': {'1. open': '839.3000',
#   '2. high': '842.1500',
#   '3. low': '832.0000',
#   '4. close': '834.2000',
#   '5. volume': '502957'},
#  '2024-11-26': {'1. open': '844.7500',
#   '2. high': '846.7000',
#   '3. low': '835.2000',
#   '4. close': '839.3500',
#   '5. volume': '448647'},
#  '2024-11-25': {'1. open': '826.2500',
#   '2. high': '849.3000',
#   '3. low': '825.9500',
#   '4. close': '844.7500',
#   '5. volume': '1612713'},
#  '2024-11-22': {'1. open': '785.6500',
#   '2. high': '819.7500',
#   '3. low': '784.3000',
#   '4. close': '816.0500',
#   '5. volume': '1534393'},
#  '2024-11-21': {'1. open': '800.0000',
#   '2. high': '800.0000',
#   '3. low': '761.6500',
#   '4. close': '780.8500',
#   '5. volume': '804079'},
#  '2024-11-19': {'1. open': '817.5500',
#   '2. high': '820.1000',
#   '3. low': '800.1000',
#   '4. close': '802.0000',
#   '5. volume': '467072'},
#  '2024-11-18': {'1. open': '810.0500',
#   '2. high': '816.6500',
#   '3. low': '799.2000',
#   '4. close': '813.7000',
#   '5. volume': '378989'},
#  '2024-11-14': {'1. open': '809.9500',
#   '2. high': '817.8500',
#   '3. low': '801.1000',
#   '4. close': '804.0500',
#   '5. volume': '720597'},
#  '2024-11-13': {'1. open': '822.5000',
#   '2. high': '831.6500',
#   '3. low': '804.4500',
#   '4. close': '808.3500',
#   '5. volume': '454522'},
#  '2024-11-12': {'1. open': '851.0000',
#   '2. high': '853.0000',
#   '3. low': '824.1000',
#   '4. close': '826.4000',
#   '5. volume': '467134'},
#  '2024-11-11': {'1. open': '847.0000',
#   '2. high': '853.6500',
#   '3. low': '841.4500',
#   '4. close': '847.8000',
#   '5. volume': '1417460'},
#  '2024-11-08': {'1. open': '860.0000',
#   '2. high': '863.6500',
#   '3. low': '834.3000',
#   '4. close': '843.2500',
#   '5. volume': '1106664'},
#  '2024-11-07': {'1. open': '860.0500',
#   '2. high': '862.4500',
#   '3. low': '846.7000',
#   '4. close': '859.2500',
#   '5. volume': '494821'},
#  '2024-11-06': {'1. open': '850.0000',
#   '2. high': '861.0000',
#   '3. low': '846.2000',
#   '4. close': '854.7500',
#   '5. volume': '896339'},
#  '2024-11-05': {'1. open': '829.0000',
#   '2. high': '851.2000',
#   '3. low': '826.1000',
#   '4. close': '849.2000',
#   '5. volume': '1335383'},
#  '2024-11-04': {'1. open': '822.6500',
#   '2. high': '837.5000',
#   '3. low': '807.0500',
#   '4. close': '829.8500',
#   '5. volume': '458939'},
#  '2024-10-31': {'1. open': '821.9500',
#   '2. high': '828.0000',
#   '3. low': '813.4500',
#   '4. close': '820.5000',
#   '5. volume': '497763'},
#  '2024-10-30': {'1. open': '830.0000',
#   '2. high': '832.9000',
#   '3. low': '821.0500',
#   '4. close': '822.4000',
#   '5. volume': '322347'},
#  '2024-10-29': {'1. open': '796.5000',
#   '2. high': '834.5000',
#   '3. low': '790.5000',
#   '4. close': '832.6500',
#   '5. volume': '1593501'},
#  '2024-10-28': {'1. open': '783.2000',
#   '2. high': '803.9500',
#   '3. low': '783.2000',
#   '4. close': '792.0500',
#   '5. volume': '675658'},
#  '2024-10-25': {'1. open': '798.4500',
#   '2. high': '800.0000',
#   '3. low': '772.0500',
#   '4. close': '780.6000',
#   '5. volume': '650630'},
#  '2024-10-24': {'1. open': '786.0500',
#   '2. high': '796.8000',
#   '3. low': '784.5000',
#   '4. close': '794.7000',
#   '5. volume': '183971'},
#  '2024-10-23': {'1. open': '790.0000',
#   '2. high': '792.5000',
#   '3. low': '779.6000',
#   '4. close': '785.9500',
#   '5. volume': '467975'},
#  '2024-10-22': {'1. open': '814.1500',
#   '2. high': '816.3500',
#   '3. low': '787.6000',
#   '4. close': '790.4500',
#   '5. volume': '604778'},
#  '2024-10-21': {'1. open': '822.0500',
#   '2. high': '826.3500',
#   '3. low': '809.1000',
#   '4. close': '814.1500',
#   '5. volume': '584223'},
#  '2024-10-18': {'1. open': '811.0000',
#   '2. high': '822.4000',
#   '3. low': '803.1000',
#   '4. close': '819.9500',
#   '5. volume': '429099'},
#  '2024-10-17': {'1. open': '806.0500',
#   '2. high': '819.2500',
#   '3. low': '806.0500',
#   '4. close': '810.9000',
#   '5. volume': '948591'},
#  '2024-10-16': {'1. open': '801.0500',
#   '2. high': '808.9000',
#   '3. low': '801.0500',
#   '4. close': '805.8500',
#   '5. volume': '142406'},
#  '2024-10-15': {'1. open': '805.0000',
#   '2. high': '807.6000',
#   '3. low': '801.5000',
#   '4. close': '804.6000',
#   '5. volume': '314354'},
#  '2024-10-14': {'1. open': '800.1500',
#   '2. high': '809.0000',
#   '3. low': '800.1500',
#   '4. close': '805.2500',
#   '5. volume': '755286'},
#  '2024-10-11': {'1. open': '797.0000',
#   '2. high': '802.5000',
#   '3. low': '793.0000',
#   '4. close': '800.0000',
#   '5. volume': '381115'},
#  '2024-10-10': {'1. open': '799.9000',
#   '2. high': '804.3500',
#   '3. low': '795.0500',
#   '4. close': '796.9500',
#   '5. volume': '163966'},
#  '2024-10-09': {'1. open': '787.9500',
#   '2. high': '805.0000',
#   '3. low': '782.5500',
#   '4. close': '797.0000',
#   '5. volume': '807499'},
#  '2024-10-08': {'1. open': '771.1000',
#   '2. high': '784.5000',
#   '3. low': '771.1000',
#   '4. close': '782.0500',
#   '5. volume': '295906'},
#  '2024-10-07': {'1. open': '797.0500',
#   '2. high': '803.9000',
#   '3. low': '765.5500',
#   '4. close': '769.8000',
#   '5. volume': '1587972'},
#  '2024-10-04': {'1. open': '790.3000',
#   '2. high': '809.6500',
#   '3. low': '785.2000',
#   '4. close': '796.6000',
#   '5. volume': '1154183'},
#  '2024-10-03': {'1. open': '787.4000',
#   '2. high': '803.9500',
#   '3. low': '784.3500',
#   '4. close': '794.3500',
#   '5. volume': '768391'},
#  '2024-10-01': {'1. open': '788.9500',
#   '2. high': '799.7500',
#   '3. low': '788.2500',
#   '4. close': '797.0000',
#   '5. volume': '227883'},
#  '2024-09-30': {'1. open': '801.1500',
#   '2. high': '802.5000',
#   '3. low': '786.1500',
#   '4. close': '787.6000',
#   '5. volume': '1054719'},
#  '2024-09-27': {'1. open': '802.0000',
#   '2. high': '807.8500',
#   '3. low': '798.4000',
#   '4. close': '802.6500',
#   '5. volume': '669965'},
#  '2024-09-26': {'1. open': '795.1500',
#   '2. high': '803.0000',
#   '3. low': '791.5500',
#   '4. close': '801.9000',
#   '5. volume': '432917'},
#  '2024-09-25': {'1. open': '798.2500',
#   '2. high': '798.2500',
#   '3. low': '788.6500',
#   '4. close': '792.9500',
#   '5. volume': '524539'},
#  '2024-09-24': {'1. open': '800.0000',
#   '2. high': '804.1000',
#   '3. low': '796.6500',
#   '4. close': '798.3500',
#   '5. volume': '427650'},
#  '2024-09-23': {'1. open': '785.0500',
#   '2. high': '804.9000',
#   '3. low': '785.0000',
#   '4. close': '801.8000',
#   '5. volume': '1415077'},
#  '2024-09-20': {'1. open': '794.0500',
#   '2. high': '794.4000',
#   '3. low': '779.5000',
#   '4. close': '781.9000',
#   '5. volume': '1481791'},
#  '2024-09-19': {'1. open': '794.1500',
#   '2. high': '801.2500',
#   '3. low': '784.1000',
#   '4. close': '790.3500',
#   '5. volume': '402071'},
#  '2024-09-18': {'1. open': '783.5500',
#   '2. high': '794.5000',
#   '3. low': '781.3000',
#   '4. close': '792.3500',
#   '5. volume': '681430'},
#  '2024-09-17': {'1. open': '786.0000',
#   '2. high': '787.5000',
#   '3. low': '780.6500',
#   '4. close': '783.0500',
#   '5. volume': '240500'},
#  '2024-09-16': {'1. open': '793.4500',
#   '2. high': '795.3000',
#   '3. low': '784.1000',
#   '4. close': '785.4500',
#   '5. volume': '624666'},
#  '2024-09-13': {'1. open': '790.8500',
#   '2. high': '795.0000',
#   '3. low': '784.8500',
#   '4. close': '790.5500',
#   '5. volume': '1064575'},
#  '2024-09-12': {'1. open': '775.0000',
#   '2. high': '789.7000',
#   '3. low': '772.9000',
#   '4. close': '788.0500',
#   '5. volume': '312891'},
#  '2024-09-11': {'1. open': '781.6500',
#   '2. high': '788.0000',
#   '3. low': '765.6500',
#   '4. close': '768.3000',
#   '5. volume': '521913'},
#  '2024-09-10': {'1. open': '788.6500',
#   '2. high': '788.9500',
#   '3. low': '777.6500',
#   '4. close': '782.6000',
#   '5. volume': '582017'},
#  '2024-09-09': {'1. open': '785.0000',
#   '2. high': '788.0500',
#   '3. low': '771.3000',
#   '4. close': '784.3000',
#   '5. volume': '1433332'},
#  '2024-09-06': {'1. open': '813.9000',
#   '2. high': '813.9000',
#   '3. low': '777.0500',
#   '4. close': '782.6000',
#   '5. volume': '2498701'},
#  '2024-09-05': {'1. open': '818.0000',
#   '2. high': '821.9000',
#   '3. low': '814.3000',
#   '4. close': '818.6000',
#   '5. volume': '318031'},
#  '2024-09-04': {'1. open': '813.0000',
#   '2. high': '818.6500',
#   '3. low': '813.0000',
#   '4. close': '816.5000',
#   '5. volume': '278846'},
#  '2024-09-03': {'1. open': '821.2000',
#   '2. high': '825.9000',
#   '3. low': '816.7500',
#   '4. close': '824.7500',
#   '5. volume': '293326'},
#  '2024-09-02': {'1. open': '816.4500',
#   '2. high': '825.3000',
#   '3. low': '813.0000',
#   '4. close': '822.1000',
#   '5. volume': '1129356'},
#  '2024-08-30': {'1. open': '818.4500',
#   '2. high': '820.3500',
#   '3. low': '814.3000',
#   '4. close': '815.6500',
#   '5. volume': '598533'},
#  '2024-08-29': {'1. open': '809.3500',
#   '2. high': '815.9500',
#   '3. low': '807.3000',
#   '4. close': '814.5000',
#   '5. volume': '271349'},
#  '2024-08-28': {'1. open': '813.8000',
#   '2. high': '817.1000',
#   '3. low': '806.9000',
#   '4. close': '809.3000',
#   '5. volume': '196716'},
#  '2024-08-27': {'1. open': '816.8500',
#   '2. high': '819.3000',
#   '3. low': '811.0500',
#   '4. close': '815.1500',
#   '5. volume': '464853'},
#  '2024-08-26': {'1. open': '819.3500',
#   '2. high': '823.3500',
#   '3. low': '814.2000',
#   '4. close': '815.3500',
#   '5. volume': '1278721'},
#  '2024-08-23': {'1. open': '821.0500',
#   '2. high': '821.7000',
#   '3. low': '814.2000',
#   '4. close': '815.2500',
#   '5. volume': '560060'},
#  '2024-08-22': {'1. open': '819.8500',
#   '2. high': '823.7000',
#   '3. low': '817.4000',
#   '4. close': '820.1500',
#   '5. volume': '494896'},
#  '2024-08-21': {'1. open': '820.0000',
#   '2. high': '821.0000',
#   '3. low': '811.4000',
#   '4. close': '815.8000',
#   '5. volume': '248423'},
#  '2024-08-20': {'1. open': '818.7500',
#   '2. high': '822.9000',
#   '3. low': '813.2000',
#   '4. close': '820.0000',
#   '5. volume': '308095'},
#  '2024-08-19': {'1. open': '814.0500',
#   '2. high': '825.0000',
#   '3. low': '812.3500',
#   '4. close': '813.6500',
#   '5. volume': '743917'},
#  '2024-08-16': {'1. open': '803.5000',
#   '2. high': '815.1000',
#   '3. low': '803.2000',
#   '4. close': '812.4500',
#   '5. volume': '768630'},
#  '2024-08-14': {'1. open': '800.7000',
#   '2. high': '809.0000',
#   '3. low': '800.4000',
#   '4. close': '802.9500',
#   '5. volume': '287718'},
#  '2024-08-13': {'1. open': '813.1000',
#   '2. high': '819.4000',
#   '3. low': '795.1000',
#   '4. close': '797.3000',
#   '5. volume': '641102'},
#  '2024-08-12': {'1. open': '819.2000',
#   '2. high': '822.6000',
#   '3. low': '810.8500',
#   '4. close': '813.0000',
#   '5. volume': '1142861'},
#  '2024-08-09': {'1. open': '816.8000',
#   '2. high': '829.9000',
#   '3. low': '809.8500',
#   '4. close': '824.2000',
#   '5. volume': '822817'}}

# %%
import pandas as pd
df = pd.DataFrame(daily).T
df
# Out:
#              1. open   2. high    3. low  4. close 5. volume
# 2025-01-03  801.9000  809.7000  792.2500  793.5000    387698
# 2025-01-02  795.0000  802.4000  786.3000  801.0500    711599
# 2025-01-01  796.8500  798.5000  789.6000  793.3500    356031
# 2024-12-31  788.7500  798.9500  787.0000  795.0500    283620
# 2024-12-30  802.7000  808.0000  785.2000  788.3000    686161
# ...              ...       ...       ...       ...       ...
# 2024-08-16  803.5000  815.1000  803.2000  812.4500    768630
# 2024-08-14  800.7000  809.0000  800.4000  802.9500    287718
# 2024-08-13  813.1000  819.4000  795.1000  797.3000    641102
# 2024-08-12  819.2000  822.6000  810.8500  813.0000   1142861
# 2024-08-09  816.8000  829.9000  809.8500  824.2000    822817
#
# [100 rows x 5 columns]

# %%
df.dtypes
# Out:
# 1. open      object
# 2. high      object
# 3. low       object
# 4. close     object
# 5. volume    object
# dtype: object

# %%
df = df.astype(float).round(2)
df
# Out:
#             1. open  2. high  3. low  4. close  5. volume
# 2025-01-03   801.90   809.70  792.25    793.50   387698.0
# 2025-01-02   795.00   802.40  786.30    801.05   711599.0
# 2025-01-01   796.85   798.50  789.60    793.35   356031.0
# 2024-12-31   788.75   798.95  787.00    795.05   283620.0
# 2024-12-30   802.70   808.00  785.20    788.30   686161.0
# ...             ...      ...     ...       ...        ...
# 2024-08-16   803.50   815.10  803.20    812.45   768630.0
# 2024-08-14   800.70   809.00  800.40    802.95   287718.0
# 2024-08-13   813.10   819.40  795.10    797.30   641102.0
# 2024-08-12   819.20   822.60  810.85    813.00  1142861.0
# 2024-08-09   816.80   829.90  809.85    824.20   822817.0
#
# [100 rows x 5 columns]

# %%
df.dtypes
# Out:
# 1. open      float64
# 2. high      float64
# 3. low       float64
# 4. close     float64
# 5. volume    float64
# dtype: object

# %%
# Convert index to datatime
df.index = pd.to_datetime(df.index)
df.index
# Out:
# DatetimeIndex(['2025-01-03', '2025-01-02', '2025-01-01', '2024-12-31',
#                '2024-12-30', '2024-12-27', '2024-12-26', '2024-12-24',
#                '2024-12-23', '2024-12-20', '2024-12-19', '2024-12-18',
#                '2024-12-17', '2024-12-16', '2024-12-13', '2024-12-12',
#                '2024-12-11', '2024-12-10', '2024-12-09', '2024-12-06',
#                '2024-12-05', '2024-12-04', '2024-12-03', '2024-12-02',
#                '2024-11-29', '2024-11-28', '2024-11-27', '2024-11-26',
#                '2024-11-25', '2024-11-22', '2024-11-21', '2024-11-19',
#                '2024-11-18', '2024-11-14', '2024-11-13', '2024-11-12',
#                '2024-11-11', '2024-11-08', '2024-11-07', '2024-11-06',
#                '2024-11-05', '2024-11-04', '2024-10-31', '2024-10-30',
#                '2024-10-29', '2024-10-28', '2024-10-25', '2024-10-24',
#                '2024-10-23', '2024-10-22', '2024-10-21', '2024-10-18',
#                '2024-10-17', '2024-10-16', '2024-10-15', '2024-10-14',
#                '2024-10-11', '2024-10-10', '2024-10-09', '2024-10-08',
#                '2024-10-07', '2024-10-04', '2024-10-03', '2024-10-01',
#                '2024-09-30', '2024-09-27', '2024-09-26', '2024-09-25',
#                '2024-09-24', '2024-09-23', '2024-09-20', '2024-09-19',
#                '2024-09-18', '2024-09-17', '2024-09-16', '2024-09-13',
#                '2024-09-12', '2024-09-11', '2024-09-10', '2024-09-09',
#                '2024-09-06', '2024-09-05', '2024-09-04', '2024-09-03',
#                '2024-09-02', '2024-08-30', '2024-08-29', '2024-08-28',
#                '2024-08-27', '2024-08-26', '2024-08-23', '2024-08-22',
#                '2024-08-21', '2024-08-20', '2024-08-19', '2024-08-16',
#                '2024-08-14', '2024-08-13', '2024-08-12', '2024-08-09'],
#               dtype='datetime64[ns]', freq=None)

# %%
df
# Out:
#             1. open  2. high  3. low  4. close  5. volume
# 2025-01-03   801.90   809.70  792.25    793.50   387698.0
# 2025-01-02   795.00   802.40  786.30    801.05   711599.0
# 2025-01-01   796.85   798.50  789.60    793.35   356031.0
# 2024-12-31   788.75   798.95  787.00    795.05   283620.0
# 2024-12-30   802.70   808.00  785.20    788.30   686161.0
# ...             ...      ...     ...       ...        ...
# 2024-08-16   803.50   815.10  803.20    812.45   768630.0
# 2024-08-14   800.70   809.00  800.40    802.95   287718.0
# 2024-08-13   813.10   819.40  795.10    797.30   641102.0
# 2024-08-12   819.20   822.60  810.85    813.00  1142861.0
# 2024-08-09   816.80   829.90  809.85    824.20   822817.0
#
# [100 rows x 5 columns]

# %%
df.index.name = "Date"
df
# Out:
#             1. open  2. high  3. low  4. close  5. volume
# Date
# 2025-01-03   801.90   809.70  792.25    793.50   387698.0
# 2025-01-02   795.00   802.40  786.30    801.05   711599.0
# 2025-01-01   796.85   798.50  789.60    793.35   356031.0
# 2024-12-31   788.75   798.95  787.00    795.05   283620.0
# 2024-12-30   802.70   808.00  785.20    788.30   686161.0
# ...             ...      ...     ...       ...        ...
# 2024-08-16   803.50   815.10  803.20    812.45   768630.0
# 2024-08-14   800.70   809.00  800.40    802.95   287718.0
# 2024-08-13   813.10   819.40  795.10    797.30   641102.0
# 2024-08-12   819.20   822.60  810.85    813.00  1142861.0
# 2024-08-09   816.80   829.90  809.85    824.20   822817.0
#
# [100 rows x 5 columns]

# %%
df.to_csv("SBIPrice.csv")

# %% [markdown]
# ## Visulalize the data with Candlestick chart

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.columns
# Out:
# Index(['1. open', '2. high', '3. low', '4. close', '5. volume'], dtype='object')

# %%
import plotly.graph_objects as go

# %%
fig = go.Figure(
    data = [
        go.Candlestick(
            x = df.index,
            open = df["1. open"],
            high = df["2. high"],
            low = df["3. low"],
            close = df["4. close"] 
        )
    ]
)

fig.update_layout(width=1200, height=800)

fig.show()

# %% [markdown]
# ## Create a class to get stock details for any stock

# %%
class StockAPI:
    def __init__(self):
        self.url = 'https://alpha-vantage.p.rapidapi.com/query'
        self.headers = {
            'x-rapidapi-key':os.getenv('API_KEY'),
            'x-rapidapi-host':'alpha-vantage.p.rapidapi.com',
        }
        
    def search_symbol(self, company_name):
        querystring = {
            'datatpe':'json',
            'keywards':company_name,
            'function':'SYMBOL_SEARCH'
        }
        response = requests.get(self.url, headers = self.headers, params = querystring)
        return response.json()

    def get_stock_data(self, symbol):
        querystring = {
            "function": "TIME_SERIES_DAILY",
            "symbol": symbol,
            "outputsize": "compact",
            "datatype": "json",
        }
        response = requests.get(url, headers=self.headers, params=querystring)
        data = response.json()["Time Series (Daily)"]
        df = pd.DataFrame(data).T
        df = df.astype(float).round(2)
        df.index = pd.to_datetime(df.index)
        df.index.name = "Date"
        return df

    def plot_candlestick(self, df):
        fig = go.Figure(
            data=[
                go.Candlestick(
                    x=df.index,
                    open=df["1. open"],
                    high=df["2. high"],
                    low=df["3. low"],
                    close=df["4. close"],
                )
            ]
        )
        fig.update_layout(width=1200, height=800)
        fig.show()

# %%
client = StockAPI()
client.search_symbol(company_name='HDFC Bank')
# Out:
# {'Error Message': 'Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for SYMBOL_SEARCH.'}

# %%
df2 = client.get_stock_data(symbol='HDFCBANK.BSE')
df2
# Out:
#             1. open  2. high   3. low  4. close  5. volume
# Date
# 2025-01-03  1794.80  1794.80  1746.30   1749.30   402803.0
# 2025-01-02  1780.50  1803.00  1774.10   1793.35    79075.0
# 2025-01-01  1775.00  1794.40  1762.00   1782.45   110695.0
# 2024-12-31  1770.05  1781.35  1768.00   1772.45   107155.0
# 2024-12-30  1794.95  1815.00  1771.35   1778.70   292506.0
# ...             ...      ...      ...       ...        ...
# 2024-08-19  1635.75  1637.05  1623.15   1631.55   595399.0
# 2024-08-16  1622.00  1634.60  1611.60   1632.35   977686.0
# 2024-08-14  1607.90  1613.55  1603.10   1607.90   305981.0
# 2024-08-13  1628.00  1631.55  1601.20   1603.60   970561.0
# 2024-08-12  1641.25  1675.60  1641.25   1661.05  1536607.0
#
# [100 rows x 5 columns]

# %%
df2.to_csv('HDFCPrice.csv')

# %%
client.plot_candlestick(df2)

# %% [markdown]
# ## get the details for tesla stock from US

# %%
client.search_symbol(company_name='Tesla')
# Out:
# {'Error Message': 'Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for SYMBOL_SEARCH.'}

# %%
df3 = client.get_stock_data(symbol = 'TSLA')
df3
# Out:
#             1. open  2. high  3. low  4. close    5. volume
# Date
# 2025-01-03   381.48   411.88  379.45    410.44   95423329.0
# 2025-01-02   390.10   392.73  373.04    379.28  109710749.0
# 2024-12-31   423.79   427.93  402.54    403.84   76825121.0
# 2024-12-30   419.40   427.00  415.75    417.41   64941012.0
# 2024-12-27   449.52   450.00  426.50    431.66   82666821.0
# ...             ...      ...     ...       ...          ...
# 2024-08-19   217.07   222.98  214.09    222.72   76435222.0
# 2024-08-16   211.15   219.80  210.80    216.12   88765122.0
# 2024-08-15   205.02   215.88  204.82    214.14   89848530.0
# 2024-08-14   207.39   208.44  198.75    201.38   70250014.0
# 2024-08-13   198.47   208.49  197.06    207.83   76247387.0
#
# [100 rows x 5 columns]

# %%
client.plot_candlestick(df3)
